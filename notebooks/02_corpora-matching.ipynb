# %% [markdown]
# # Lecture 02. Corpora and Dictionaries
#
# Natural Language Processing for Law and Social Science<br>
# Elliott Ash, ETH Zurich

# %%
# set random seed
import numpy as np
np.random.seed(4)

# %% [markdown]
# # Web Scraping
#
# There are several ways to obtain data from the internet. Below are the links to tutorial for these methods:
#
# 1. Scraping with [selenium](https://selenium-python.readthedocs.io/) (an example [here](https://towardsdatascience.com/how-to-use-selenium-to-web-scrape-with-example-80f9b23a843a): useful if the webpage contains JS scripts)
# 2. Retrieving raw html with [beautifulsoup](https://beautiful-soup-4.readthedocs.io/en/latest/)
# 3. Quering [REST Api](https://restfulapi.net/) (a nice example [here](https://betterprogramming.pub/extracting-rest-api-data-using-python-with-an-example-e800b03bb62e))

# %% [markdown]
# ## Downloading URL's

# %%
import urllib.request as urllib # Python's module for accessing web pages
url = 'https://goo.gl/VRF8Xs' # shortened URL for court case
page = urllib.urlopen(url) # open the web page

html = page.read() # read web page contents as a string
print(html[:400])  # print first 400 characters
print()
print(html[-400:]) # print last 400 characters
print()
print(len(html),'characters in string.')   # print length of string
# Out:
# b''
#
# b''
#
# 0 characters in string.

# %% [markdown]
# ## Parsing HTML

# %%
# Parse raw HTML
# !pip install beautifulsoup4
from bs4 import BeautifulSoup # package for parsing HTML
soup = BeautifulSoup(html, "html.parser") # parse html of web page
print(soup.title) # example usage: print title item
# Out:
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# None

# %%
# extract text
text = soup.get_text() # get text (remove HTML markup)
lines = text.splitlines() # split string into separate lines
print(len(lines)) # print number of lines
# Out:
# 0

# %%
lines = [line for line in lines if line != ''] # drop empty lines
print(len(lines)) # print number of lines
# Out:
# 0

# %%
print(lines[:20]) # print first 20 lines
# Out:
# []

# %% [markdown]
# ## Removing unicode characters

# %%
# !pip install unidecode
from unidecode import unidecode # package for removing unicode
uncode_str = 'Visualizations\xa0'
fixed = unidecode(uncode_str) # example usage
print([uncode_str],[fixed]) # print cleaned string (replaced with a space)
# Out:
# ['Visualizations\xa0'] ['Visualizations ']

# %% [markdown]
# # Loading and Inspecting Data with Pandas
#
# These notebooks are more about methods than answering a specific research questions. However, while going through them, it is useful to keep in mind a potential research questions with economic relevance. We will be working with court cases and have the text of the opinion written by the judge,its affiliation, as well as some information about type of opinion, other judges on the panel and the number of cites for each opinion
#
# **Given these data, what could be interesting to investigate?**

# %% [markdown]
# When dealing with inspecting or cleaning data in python pandas is your best friend and [here](https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf)'s a useful cheat sheet

# %%
#import warnings; warnings.simplefilter('ignore')
# !pip install pandas
import pandas as pd
df = pd.read_csv('sc_cases.zip',compression='gzip')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 820 entries, 0 to 819
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   case_name       786 non-null    str
#  1   opinion_type    820 non-null    str
#  2   date_standard   820 non-null    str
#  3   authorship      820 non-null    str
#  4   x_republican    803 non-null    float64
#  5   maj_judges      786 non-null    str
#  6   dissent_judges  786 non-null    str
#  7   topic_id        786 non-null    float64
#  8   cite_count      812 non-null    float64
#  9   opinion_text    820 non-null    str
# dtypes: float64(3), str(7)
# memory usage: 64.2 KB

# %%
df.head()
# Out:
#                                            case_name opinion_type  \
# 0                ERICK CORNELL CLAY v. UNITED STATES     majority
# 1  HILLSIDE DAIRY INC., A&A DAIRY, L&S DAIRY, AND...     majority
# 2    CHARLES RUSSELL RHINES v. DOUGLAS WEBER, WARDEN     majority
# 3                                                NaN     majority
# 4        STATE OF ALASKA v. UNITED STATES OF AMERICA     majority
#
#   date_standard authorship  x_republican  \
# 0    2003-03-04   GINSBURG           0.0
# 1    2003-06-09    STEVENS           1.0
# 2    2005-03-30   O'CONNOR           1.0
# 3    2005-04-15    KENNEDY           1.0
# 4    2005-06-06    KENNEDY           1.0
#
#                                           maj_judges  \
# 0  ['BREYER, STEPHEN', 'GINSBURG, RUTH', 'KENNEDY...
# 1  ['BREYER, STEPHEN', 'GINSBURG, RUTH', 'KENNEDY...
# 2  ['BREYER, STEPHEN', 'GINSBURG, RUTH', 'KENNEDY...
# 3                                                NaN
# 4  ['BREYER, STEPHEN', 'GINSBURG, RUTH', 'KENNEDY...
#
#                                       dissent_judges  topic_id  cite_count  \
# 0                                                 []       1.0      2926.0
# 1                               ['THOMAS, CLARENCE']       8.0       117.0
# 2                                                 []       1.0     23364.0
# 3                                                NaN       NaN         6.0
# 4  ['REHNQUIST, WILLIAM', 'SCALIA, ANTONIN', 'THO...      10.0        84.0
#
#                                         opinion_text
# 0  JUSTICE GINSBURG delivered the opinion of the ...
# 1  Justice Stevens delivered the opinion of the C...
# 2  Justice O'Connor delivered the opinion of the ...
# 3  Justice Kennedy, Circuit Justice. \n\n This is...
# 4  Justice Kennedy delivered the opinion of the C...

# %%
# drop missing
df = df.dropna()
df.head()
# Out:
#                                            case_name opinion_type  \
# 0                ERICK CORNELL CLAY v. UNITED STATES     majority
# 1  HILLSIDE DAIRY INC., A&A DAIRY, L&S DAIRY, AND...     majority
# 2    CHARLES RUSSELL RHINES v. DOUGLAS WEBER, WARDEN     majority
# 4        STATE OF ALASKA v. UNITED STATES OF AMERICA     majority
# 5  REGINALD A. WILKINSON, DIRECTOR, OHIO DEPARTME...     majority
#
#   date_standard authorship  x_republican  \
# 0    2003-03-04   GINSBURG           0.0
# 1    2003-06-09    STEVENS           1.0
# 2    2005-03-30   O'CONNOR           1.0
# 4    2005-06-06    KENNEDY           1.0
# 5    2005-06-13    KENNEDY           1.0
#
#                                           maj_judges  \
# 0  ['BREYER, STEPHEN', 'GINSBURG, RUTH', 'KENNEDY...
# 1  ['BREYER, STEPHEN', 'GINSBURG, RUTH', 'KENNEDY...
# 2  ['BREYER, STEPHEN', 'GINSBURG, RUTH', 'KENNEDY...
# 4  ['BREYER, STEPHEN', 'GINSBURG, RUTH', 'KENNEDY...
# 5  ['BREYER, STEPHEN', 'GINSBURG, RUTH', 'KENNEDY...
#
#                                       dissent_judges  topic_id  cite_count  \
# 0                                                 []       1.0      2926.0
# 1                               ['THOMAS, CLARENCE']       8.0       117.0
# 2                                                 []       1.0     23364.0
# 4  ['REHNQUIST, WILLIAM', 'SCALIA, ANTONIN', 'THO...      10.0        84.0
# 5                                                 []       4.0      4230.0
#
#                                         opinion_text
# 0  JUSTICE GINSBURG delivered the opinion of the ...
# 1  Justice Stevens delivered the opinion of the C...
# 2  Justice O'Connor delivered the opinion of the ...
# 4  Justice Kennedy delivered the opinion of the C...
# 5  Justice Kennedy delivered the opinion of the C...

# %%
# Number of label categories (e.g. judges)
df['authorship'].describe()
# Out:
# count        781
# unique        27
# top       SCALIA
# freq          86
# Name: authorship, dtype: object

# %%
# tabulations of label categories 
df['authorship'].value_counts()
# Out:
# authorship
# SCALIA                                           86
# GINSBURG                                         81
# KENNEDY                                          79
# THOMAS                                           79
# BREYER                                           73
# STEVENS                                          72
# SOUTER                                           72
# O'CONNOR                                         52
# REHNQUIST                                        49
# ROBERTS                                          28
# ALITO                                            23
# Breyer                                           12
# Roberts                                          10
# Alito                                             9
# Ginsburg                                          8
# Thomas                                            8
# Scalia                                            8
# Kennedy                                           7
# Stevens                                           7
# SOTOMAYOR                                         6
# Souter                                            5
# STEVENS  AND  O'CONNOR ;  REHNQUIST ;  BREYER     2
# STEVENS  (IN PART),  BREYER  (IN PART)            1
# JUSTICE  ALITO                                    1
# BREYER ;                                          1
# ROBERTS ,  SCALIA ,  THOMAS ,  ALITO              1
# Sotomayor                                         1
# Name: count, dtype: int64

# %%
df['authorship'] = df['authorship'].str.upper()

# %%
df['authorship'].value_counts()
# Out:
# authorship
# SCALIA                                           94
# GINSBURG                                         89
# THOMAS                                           87
# KENNEDY                                          86
# BREYER                                           85
# STEVENS                                          79
# SOUTER                                           77
# O'CONNOR                                         52
# REHNQUIST                                        49
# ROBERTS                                          38
# ALITO                                            32
# SOTOMAYOR                                         7
# STEVENS  AND  O'CONNOR ;  REHNQUIST ;  BREYER     2
# STEVENS  (IN PART),  BREYER  (IN PART)            1
# JUSTICE  ALITO                                    1
# BREYER ;                                          1
# ROBERTS ,  SCALIA ,  THOMAS ,  ALITO              1
# Name: count, dtype: int64

# %%
# keep all judges through ALITO
keep_judges = df['authorship'].value_counts().index[:11]
print(keep_judges)
# Out:
# Index(['SCALIA', 'GINSBURG', 'THOMAS', 'KENNEDY', 'BREYER', 'STEVENS',
#        'SOUTER', 'O'CONNOR', 'REHNQUIST', 'ROBERTS', 'ALITO'],
#       dtype='str', name='authorship')

# %%
df = df[df['authorship'].isin(keep_judges)]
df['authorship'].value_counts()
# Out:
# authorship
# SCALIA       94
# GINSBURG     89
# THOMAS       87
# KENNEDY      86
# BREYER       85
# STEVENS      79
# SOUTER       77
# O'CONNOR     52
# REHNQUIST    49
# ROBERTS      38
# ALITO        32
# Name: count, dtype: int64

# %%
df.date_standard
# Out:
# 0      2003-03-04
# 1      2003-06-09
# 2      2005-03-30
# 4      2005-06-06
# 5      2005-06-13
#           ...
# 815    2001-04-18
# 816    2001-04-24
# 817    2001-04-24
# 818    2001-05-14
# 819    2001-05-14
# Name: date_standard, Length: 768, dtype: str

# %%
df['date_standard'] = pd.to_datetime(df['date_standard'])
df['date_standard']
# Out:
# 0     2003-03-04
# 1     2003-06-09
# 2     2005-03-30
# 4     2005-06-06
# 5     2005-06-13
#          ...
# 815   2001-04-18
# 816   2001-04-24
# 817   2001-04-24
# 818   2001-05-14
# 819   2001-05-14
# Name: date_standard, Length: 768, dtype: datetime64[us]

# %%
df['year'] = df['date_standard'].dt.year
df['year'].value_counts()
# Out:
# year
# 2001    77
# 2000    76
# 2009    74
# 2002    74
# 2004    73
# 2003    70
# 2005    70
# 2007    65
# 2010    64
# 2006    63
# 2008    62
# Name: count, dtype: int64

# %%
df['cite_count'].hist()
# Out:
# <Axes: >

# %%
import numpy as np
df['log_cite_count'] = np.log(df['cite_count'])
df['log_cite_count'].hist()
# Out:
# <Axes: >

# %% [markdown]
# Save what we have done so far.

# %%
df.to_pickle('sc_cases_cleaned.pkl',compression='gzip')
print(df)
# Out:
#                                              case_name opinion_type  \
# 0                  ERICK CORNELL CLAY v. UNITED STATES     majority
# 1    HILLSIDE DAIRY INC., A&A DAIRY, L&S DAIRY, AND...     majority
# 2      CHARLES RUSSELL RHINES v. DOUGLAS WEBER, WARDEN     majority
# 4          STATE OF ALASKA v. UNITED STATES OF AMERICA     majority
# 5    REGINALD A. WILKINSON, DIRECTOR, OHIO DEPARTME...     majority
# ..                                                 ...          ...
# 815  MICHAEL F. EASLEY, * GOVERNOR OF NORTH CAROLIN...     majority
# 816  GAIL ATWATER, et al. v. CITY OF LAGO VISTA et al.     majority
# 817  JAMES ALEXANDER, DIRECTOR, ALABAMA DEPARTMENT ...     majority
# 818  UNITED STATES v. OAKLAND CANNABIS BUYERS' COOP...     majority
# 819                     WILBERT K. ROGERS v. TENNESSEE     majority
#
#     date_standard authorship  x_republican  \
# 0      2003-03-04   GINSBURG           0.0
# 1      2003-06-09    STEVENS           1.0
# 2      2005-03-30   O'CONNOR           1.0
# 4      2005-06-06    KENNEDY           1.0
# 5      2005-06-13    KENNEDY           1.0
# ..            ...        ...           ...
# 815    2001-04-18     BREYER           0.0
# 816    2001-04-24     SOUTER           1.0
# 817    2001-04-24     SCALIA           1.0
# 818    2001-05-14     THOMAS           1.0
# 819    2001-05-14   O'CONNOR           1.0
#
#                                             maj_judges  \
# 0    ['BREYER, STEPHEN', 'GINSBURG, RUTH', 'KENNEDY...
# 1    ['BREYER, STEPHEN', 'GINSBURG, RUTH', 'KENNEDY...
# 2    ['BREYER, STEPHEN', 'GINSBURG, RUTH', 'KENNEDY...
# 4    ['BREYER, STEPHEN', 'GINSBURG, RUTH', 'KENNEDY...
# 5    ['BREYER, STEPHEN', 'GINSBURG, RUTH', 'KENNEDY...
# ..                                                 ...
# 815  ['BREYER, STEPHEN', 'GINSBURG, RUTH', "O'CONNO...
# 816  ['KENNEDY, ANTHONY', 'REHNQUIST, WILLIAM', 'SC...
# 817  ['KENNEDY, ANTHONY', "O'CONNOR, SANDRA", 'REHN...
# 818  ['BREYER, STEPHEN', 'GINSBURG, RUTH', 'KENNEDY...
# 819  ['GINSBURG, RUTH', 'KENNEDY, ANTHONY', "O'CONN...
#
#                                         dissent_judges  topic_id  cite_count  \
# 0                                                   []       1.0      2926.0
# 1                                 ['THOMAS, CLARENCE']       8.0       117.0
# 2                                                   []       1.0     23364.0
# 4    ['REHNQUIST, WILLIAM', 'SCALIA, ANTONIN', 'THO...      10.0        84.0
# 5                                                   []       4.0      4230.0
# ..                                                 ...       ...         ...
# 815  ['KENNEDY, ANTHONY', 'REHNQUIST, WILLIAM', 'SC...       2.0      1236.0
# 816  ['BREYER, STEPHEN', 'GINSBURG, RUTH', "O'CONNO...       1.0      3120.0
# 817  ['BREYER, STEPHEN', 'GINSBURG, RUTH', 'SOUTER,...       9.0      4986.0
# 818                                                 []       1.0       736.0
# 819  ['BREYER, STEPHEN', 'SCALIA, ANTONIN', 'STEVEN...       4.0      2100.0
#
#                                           opinion_text  year  log_cite_count
# 0    JUSTICE GINSBURG delivered the opinion of the ...  2003        7.981392
# 1    Justice Stevens delivered the opinion of the C...  2003        4.762174
# 2    Justice O'Connor delivered the opinion of the ...  2005       10.058952
# 4    Justice Kennedy delivered the opinion of the C...  2005        4.430817
# 5    Justice Kennedy delivered the opinion of the C...  2005        8.349957
# ..                                                 ...   ...             ...
# 815  JUSTICE BREYER delivered the opinion of the Co...  2001        7.119636
# 816  JUSTICE SOUTER delivered the opinion of the Co...  2001        8.045588
# 817  JUSTICE SCALIA delivered the opinion of the Co...  2001        8.514389
# 818  JUSTICE THOMAS delivered the opinion of the Co...  2001        6.601230
# 819  JUSTICE O'CONNOR delivered the opinion of the ...  2001        7.649693
#
# [768 rows x 12 columns]

# %% [markdown]
# ## Iterating over documents in a dataframe

# %% [markdown]
# In the following, we show how to iterate over a dataframe and three different ways of how to tokenize documents.

# %%
# !pip install spacy
# !python -m spacy download en_core_web_sm



import spacy
# more infos at https://spacy.io/
nlp = spacy.load('en_core_web_sm')
# Out:
# Collecting spacy
#   Downloading spacy-3.8.14-cp311-cp311-macosx_11_0_arm64.whl.metadata (28 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy)
#   Using cached spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy)
#   Using cached spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy)
#   Downloading murmurhash-1.0.15-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.3 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy)
#   Downloading cymem-2.0.13-cp311-cp311-macosx_11_0_arm64.whl.metadata (9.7 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy)
#   Downloading preshed-3.0.13-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.2 kB)
# Collecting thinc<8.4.0,>=8.3.12 (from spacy)
#   Downloading thinc-8.3.13-cp311-cp311-macosx_11_0_arm64.whl.metadata (14 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy)
#   Using cached wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.5.3 (from spacy)
#   Downloading srsly-2.5.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (19 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy)
#   Using cached catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting weasel<2.0.0,>=1.0.0 (from spacy)
#   Using cached weasel-1.0.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting confection<2.0.0,>=1.3.2 (from spacy)
#   Using cached confection-1.3.3-py3-none-any.whl.metadata (19 kB)
# Collecting typer<1.0.0,>=0.3.0 (from spacy)
#   Downloading typer-0.25.1-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/anaconda3/envs/tad_courses/lib/python3.11/site-packages (from spacy) (4.67.3)
# Requirement already satisfied: numpy>=1.19.0 in /opt/anaconda3/envs/tad_courses/lib/python3.11/site-packages (from spacy) (2.4.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/anaconda3/envs/tad_courses/lib/python3.11/site-packages (from spacy) (2.33.1)
# Collecting pydantic<3.0.0,>=2.0.0 (from spacy)
#   Downloading pydantic-2.13.4-py3-none-any.whl.metadata (109 kB)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/tad_courses/lib/python3.11/site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in /opt/anaconda3/envs/tad_courses/lib/python3.11/site-packages (from spacy) (82.0.1)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/tad_courses/lib/python3.11/site-packages (from spacy) (26.0)
# WARNING: Cache entry deserialization failed, entry ignored
# Collecting annotated-types>=0.6.0 (from pydantic<3.0.0,>=2.0.0->spacy)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# WARNING: Cache entry deserialization failed, entry ignored
# Collecting pydantic-core==2.46.4 (from pydantic<3.0.0,>=2.0.0->spacy)
#   Downloading pydantic_core-2.46.4-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Requirement already satisfied: typing-extensions>=4.14.1 in /opt/anaconda3/envs/tad_courses/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (4.15.0)
# WARNING: Cache entry deserialization failed, entry ignored
# Collecting typing-inspection>=0.4.2 (from pydantic<3.0.0,>=2.0.0->spacy)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/tad_courses/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/tad_courses/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/anaconda3/envs/tad_courses/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in /opt/anaconda3/envs/tad_courses/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2026.2.25)
# Collecting blis<1.4.0,>=1.3.0 (from thinc<8.4.0,>=8.3.12->spacy)
#   Downloading blis-1.3.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (7.5 kB)
# Requirement already satisfied: click>=8.2.1 in /opt/anaconda3/envs/tad_courses/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.3.3)
# Collecting shellingham>=1.3.0 (from typer<1.0.0,>=0.3.0->spacy)
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=13.8.0 (from typer<1.0.0,>=0.3.0->spacy)
#   Using cached rich-15.0.0-py3-none-any.whl.metadata (18 kB)
# WARNING: Cache entry deserialization failed, entry ignored
# Collecting annotated-doc>=0.0.2 (from typer<1.0.0,>=0.3.0->spacy)
#   Using cached annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Collecting cloudpathlib>=0.7.0 (from weasel<2.0.0,>=1.0.0->spacy)
#   Downloading cloudpathlib-0.24.0-py3-none-any.whl.metadata (16 kB)
# Collecting smart-open>=5.2.1 (from weasel<2.0.0,>=1.0.0->spacy)
#   Downloading smart_open-7.6.1-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: httpx>=0.24.0 in /opt/anaconda3/envs/tad_courses/lib/python3.11/site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.28.1)
# Requirement already satisfied: anyio in /opt/anaconda3/envs/tad_courses/lib/python3.11/site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (4.12.1)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/envs/tad_courses/lib/python3.11/site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/anaconda3/envs/tad_courses/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (0.16.0)
# Collecting markdown-it-py>=2.2.0 (from rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy)
#   Downloading markdown_it_py-4.2.0-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/envs/tad_courses/lib/python3.11/site-packages (from rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy) (2.20.0)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting wrapt (from smart-open>=5.2.1->weasel<2.0.0,>=1.0.0->spacy)
#   Using cached wrapt-2.1.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (7.4 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/tad_courses/lib/python3.11/site-packages (from jinja2->spacy) (3.0.2)
# Downloading spacy-3.8.14-cp311-cp311-macosx_11_0_arm64.whl (6.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 31.4 MB/s  0:00:00
# Using cached catalogue-2.0.10-py3-none-any.whl (17 kB)
# Using cached confection-1.3.3-py3-none-any.whl (35 kB)
# Downloading cymem-2.0.13-cp311-cp311-macosx_11_0_arm64.whl (43 kB)
# Downloading murmurhash-1.0.15-cp311-cp311-macosx_11_0_arm64.whl (27 kB)
# Downloading preshed-3.0.13-cp311-cp311-macosx_11_0_arm64.whl (137 kB)
# Downloading pydantic-2.13.4-py3-none-any.whl (472 kB)
# Downloading pydantic_core-2.46.4-cp311-cp311-macosx_11_0_arm64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 37.6 MB/s  0:00:00
# Using cached spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Using cached spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Downloading srsly-2.5.3-cp311-cp311-macosx_11_0_arm64.whl (657 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 657.5/657.5 kB 30.7 MB/s  0:00:00
# Downloading thinc-8.3.13-cp311-cp311-macosx_11_0_arm64.whl (812 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 812.1/812.1 kB 31.9 MB/s  0:00:00
# Downloading blis-1.3.3-cp311-cp311-macosx_11_0_arm64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 28.2 MB/s  0:00:00
# Downloading typer-0.25.1-py3-none-any.whl (58 kB)
# Using cached wasabi-1.1.3-py3-none-any.whl (27 kB)
# Using cached weasel-1.0.0-py3-none-any.whl (50 kB)
# Using cached annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading cloudpathlib-0.24.0-py3-none-any.whl (63 kB)
# Using cached rich-15.0.0-py3-none-any.whl (310 kB)
# Downloading markdown_it_py-4.2.0-py3-none-any.whl (91 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading smart_open-7.6.1-py3-none-any.whl (64 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Using cached wrapt-2.1.2-cp311-cp311-macosx_11_0_arm64.whl (61 kB)
# Installing collected packages: wrapt, wasabi, typing-inspection, spacy-loggers, spacy-legacy, shellingham, pydantic-core, murmurhash, mdurl, cymem, confection, cloudpathlib, catalogue, blis, annotated-types, annotated-doc, srsly, smart-open, pydantic, preshed, markdown-it-py, thinc, rich, typer, weasel, spacy
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26/26 [spacy]m25/26 [spacy]ic]-doc]
# Successfully installed annotated-doc-0.0.4 annotated-types-0.7.0 blis-1.3.3 catalogue-2.0.10 cloudpathlib-0.24.0 confection-1.3.3 cymem-2.0.13 markdown-it-py-4.2.0 mdurl-0.1.2 murmurhash-1.0.15 preshed-3.0.13 pydantic-2.13.4 pydantic-core-2.46.4 rich-15.0.0 shellingham-1.5.4 smart-open-7.6.1 spacy-3.8.14 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.5.3 thinc-8.3.13 typer-0.25.1 typing-inspection-0.4.2 wasabi-1.1.3 weasel-1.0.0 wrapt-2.1.2
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 31.2 MB/s  0:00:00m0:00:010:01
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
processed = {} # empty python dictionary for processed data
# iterate over rows
for i, row in df.iterrows():
    if i >= 10:
        break
    docid = i # make document identifier
    text = row['opinion_text']     # get text snippet
    document = nlp(text) # get sentences/tokens
    processed[docid] = document # add to dictionary

# %%
# first and second opinions
print ("opinion 1:", processed[0][:50], "\n\n", "opinion 2:", processed[1][:50])
# Out:
# opinion 1: JUSTICE GINSBURG delivered the opinion of the Court.
#
#  A motion by a federal prisoner for postconviction relief under 28 U.S.C. § 2255 is subject to a one-year time limitation that generally runs from "the date on which the judgment of conviction becomes final."
#
#  opinion 2: Justice Stevens delivered the opinion of the Court.
#
# In most of the United States, not including California, the minimum price paid to dairy farmers producing raw milk is regulated pursuant to federal marketing orders.  Those orders guarantee a uniform price for the producers,

# %% [markdown]
# Let's see in more detail what information we can extract from documents procesesd using spaCy:

# %%
for token in processed[0][:50]:
       print(token.text, token.pos_, token.dep_)
# Out:
# JUSTICE NOUN compound
# GINSBURG PROPN nsubj
# delivered VERB ROOT
# the DET det
# opinion NOUN dobj
# of ADP prep
# the DET det
# Court PROPN pobj
# . PUNCT punct
#
#
#   SPACE dep
# A DET det
# motion NOUN nsubj
# by ADP prep
# a DET det
# federal ADJ amod
# prisoner NOUN pobj
# for ADP prep
# postconviction NOUN compound
# relief NOUN pobj
# under ADP prep
# 28 NUM nummod
# U.S.C. PROPN compound
# § PROPN pobj
# 2255 NUM appos
# is AUX ROOT
# subject ADJ acomp
# to ADP prep
# a DET det
# one NUM nummod
# - PUNCT punct
# year NOUN compound
# time NOUN compound
# limitation NOUN pobj
# that PRON nsubj
# generally ADV advmod
# runs VERB relcl
# from ADP prep
# " PUNCT punct
# the DET det
# date NOUN pobj
# on ADP prep
# which PRON pobj
# the DET det
# judgment NOUN nsubj
# of ADP prep
# conviction NOUN pobj
# becomes VERB relcl
# final ADJ acomp
# . PUNCT punct
# " PUNCT punct

# %% [markdown]
# alternatively, we can preprocess with gensim

# %%
#!pip install gensim

from gensim.utils import simple_preprocess

processed = {} # empty python dictionary for processed data
# iterate over rows
for i, row in df.iterrows():
    docid = i # make document identifier
    text = row['opinion_text']     # get text snippet
    document = simple_preprocess(text) # get sentences/tokens
    processed[docid] = document # add to dictionary    
    if i > 100:
        break
# first and second opinions
print ("opinion 1:", processed[0][:50], "\n\n", "opinion 2:", processed[1][:50]) # note how simple preprocess drops punctuation
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[28], line 3
#       1 #!pip install gensim
# ----> 3 from gensim.utils import simple_preprocess
#       5 processed = {} # empty python dictionary for processed data
#       6 # iterate over rows
#
# ModuleNotFoundError: No module named 'gensim'

# %% [markdown]
# or with nltk

# %%
from nltk.tokenize import word_tokenize
#import nltk
#nltk.download('punkt')
processed = {} # empty python dictionary for processed data
# iterate over rows
for i, row in df.iterrows():
    docid = i # make document identifier
    text = row['opinion_text']     # get text snippet
    document = word_tokenize(text.lower()) # get sentences/tokens
    processed[docid] = document # add to dictionary    
    if i > 100:
        break
# first and second opinions
print ("opinion 1:", processed[0][:50], "\n\n", "opinion 2:", processed[1][:50]) # note that we just tokenize and keep all tokens
# Out:
# opinion 1: ['justice', 'ginsburg', 'delivered', 'the', 'opinion', 'of', 'the', 'court', '.', 'a', 'motion', 'by', 'a', 'federal', 'prisoner', 'for', 'postconviction', 'relief', 'under', '28', 'u.s.c', '.', '§', '2255', 'is', 'subject', 'to', 'a', 'one-year', 'time', 'limitation', 'that', 'generally', 'runs', 'from', '``', 'the', 'date', 'on', 'which', 'the', 'judgment', 'of', 'conviction', 'becomes', 'final', '.', "''", '§', '2255']
#
#  opinion 2: ['justice', 'stevens', 'delivered', 'the', 'opinion', 'of', 'the', 'court', '.', 'in', 'most', 'of', 'the', 'united', 'states', ',', 'not', 'including', 'california', ',', 'the', 'minimum', 'price', 'paid', 'to', 'dairy', 'farmers', 'producing', 'raw', 'milk', 'is', 'regulated', 'pursuant', 'to', 'federal', 'marketing', 'orders', '.', 'those', 'orders', 'guarantee', 'a', 'uniform', 'price', 'for', 'the', 'producers', ',', 'but', 'through']

# %% [markdown]
# ## Saving data

# %%
# save as python pickle
pd.to_pickle(processed, 'processed_corpus.pkl')
# delete it
import os 
os.remove('processed_corpus.pkl')

# %%
# Merging Data-frames Example
# Perform a left join:
# df_merged = pd.merge(df1,df2,on='id', how='left', validation='m:1')

# %% [markdown]
# # Quantity of Text

# %% [markdown]
# Count words per document.

# %%
def get_words_per_doc(txt):
    # split text into words and count them.
    return len(txt.split()) 

# apply to our dataframe
df['num_words'] = df['opinion_text'].apply(get_words_per_doc)
df['num_words'].hist()
# Out:
# <Axes: >

# %%
# plot length by year
ax = df.groupby('year')['num_words'].mean().plot()
ax.set_ylabel('Average Opinion Length')
import matplotlib.pyplot as plt
plt.show()

# %%
# !pip install seaborn

df['log_words'] = np.log(df['num_words'])
import seaborn as sns
sns.jointplot(data=df,x='year', y='log_words',kind='hex')
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /opt/anaconda3/envs/tad_courses/lib/python3.11/site-packages (from seaborn) (2.4.4)
# Requirement already satisfied: pandas>=1.2 in /opt/anaconda3/envs/tad_courses/lib/python3.11/site-packages (from seaborn) (3.0.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /opt/anaconda3/envs/tad_courses/lib/python3.11/site-packages (from seaborn) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/tad_courses/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/tad_courses/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/tad_courses/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/tad_courses/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/tad_courses/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.0)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/envs/tad_courses/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in /opt/anaconda3/envs/tad_courses/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/tad_courses/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/tad_courses/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2

# %% [markdown]
# Build a frequency distribution over words with `Counter`.

# %%
from collections import Counter
freqs = Counter()
for i, row in df.iterrows():
    freqs.update(row['opinion_text'].lower().split())
    if i > 100:
        break
freqs.most_common()[:20] # can use most frequent words as style/function words
# Out:
# [('the', 31600),
#  ('of', 15978),
#  ('to', 12330),
#  ('a', 8954),
#  ('that', 8521),
#  ('in', 8324),
#  ('and', 7619),
#  ('at', 5044),
#  ('for', 4496),
#  ('is', 4032),
#  ('not', 3577),
#  ('l.', 3216),
#  ('ed.', 3190),
#  ('as', 3048),
#  ('or', 2904),
#  ('s.', 2828),
#  ('§', 2738),
#  ('ct.', 2735),
#  ('court', 2615),
#  ('on', 2587)]

# %% [markdown]
# # Dictionary / Matching Methods

# %% [markdown]
# ## Sentiment Analysis

# %%
import spacy
from spacytextblob.spacytextblob import SpacyTextBlob

nlp = spacy.load('en_core_web_sm')
if 'spacytextblob' not in nlp.pipe_names:
    nlp.add_pipe('spacytextblob')

doc = nlp(df.iloc[0]["opinion_text"])
print("polarity", doc._.blob.polarity)
print("subjectivity", doc._.blob.subjectivity)
# Out:
# polarity 0.05404135338345859
# subjectivity 0.5065358709273183

# %%
# Dictionary-Based Sentiment Analysis
#nltk.download('vader_lexicon')

nlp = spacy.load('en_core_web_sm')
if 'spacytextblob' not in nlp.pipe_names:
    nlp.add_pipe('spacytextblob')
doc = nlp(df.iloc[0]["opinion_text"])
#from nltk.sentiment.vader import SentimentIntensityAnalyzer
#sid = SentimentIntensityAnalyzer()
#polarity = sid.polarity_scores(text)
print("polarity", doc._.blob.polarity) # sentimentintensityanalayzer nltk: {'neg': 0.134, 'neu': 0.785, 'pos': 0.081, 'compound': -0.9999}
print ("subjectivity", doc._.blob.subjectivity)
# Out:
# polarity 0.05404135338345859
# subjectivity 0.5065358709273183

# %%
# sample 10% of the dataset
dfs = df.sample(frac=.1) 
# apply compound sentiment score to data-frame
def get_sentiment(snippet):
    #return sid.polarity_scores(snippet)['compound']
    return nlp(snippet)._.polarity
dfs['sentiment'] = dfs['opinion_text'].apply(get_sentiment)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[46], line 7
#       4 def get_sentiment(snippet):
#       5     #return sid.polarity_scores(snippet)['compound']
#       6     return nlp(snippet)._.polarity
# ----> 7 dfs['sentiment'] = dfs['opinion_text'].apply(get_sentiment)
#
# File /opt/anaconda3/envs/tad_courses/lib/python3.11/site-packages/pandas/core/series.py:5084, in Series.apply(self, func, args, by_row, **kwargs)
#    4960 def apply(
#    4961     self,
#    4962     func: AggFuncType,
#    (...)   4966     **kwargs,
#    4967 ) -> DataFrame | Series:
#    4968     """
#    4969     Invoke function on values of Series.
#    4970
#    (...)   5076     dtype: float64
#    5077     """
#    5078     return SeriesApply(
#    5079         self,
#    5080         func,
#    5081         by_row=by_row,
#    5082         args=args,
#    5083         kwargs=kwargs,
# -> 5084     ).apply()
#
# File /opt/anaconda3/envs/tad_courses/lib/python3.11/site-packages/pandas/core/apply.py:1520, in SeriesApply.apply(self)
#    1517     return self.apply_compat()
#    1519 # self.func is Callable
# -> 1520 return self.apply_standard()
#
# File /opt/anaconda3/envs/tad_courses/lib/python3.11/site-packages/pandas/core/apply.py:1578, in SeriesApply.apply_standard(self)
#    1576 else:
#    1577     curried = func
# -> 1578 mapped = obj._map_values(mapper=curried)
#    1580 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1581     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1582     #  See also GH#25959 regarding EA support
#    1583     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File /opt/anaconda3/envs/tad_courses/lib/python3.11/site-packages/pandas/core/base.py:1020, in IndexOpsMixin._map_values(self, mapper, na_action)
#    1017 arr = self._values
#    1019 if isinstance(arr, ExtensionArray):
# -> 1020     return arr.map(mapper, na_action=na_action)
#    1022 return algorithms.map_array(arr, mapper, na_action=na_action)
#
# File /opt/anaconda3/envs/tad_courses/lib/python3.11/site-packages/pandas/core/arrays/base.py:2744, in ExtensionArray.map(self, mapper, na_action)
#    2724 def map(self, mapper, na_action: Literal["ignore"] | None = None):
#    2725     """
#    2726     Map values using an input mapping or function.
#    2727
#    (...)   2742         a MultiIndex will be returned.
#    2743     """
# -> 2744     return map_array(self, mapper, na_action=na_action)
#
# File /opt/anaconda3/envs/tad_courses/lib/python3.11/site-packages/pandas/core/algorithms.py:1710, in map_array(arr, mapper, na_action)
#    1708 values = arr.astype(object, copy=False)
#    1709 if na_action is None:
# -> 1710     return lib.map_infer(values, mapper)
#    1711 else:
#    1712     return lib.map_infer_mask(values, mapper, mask=isna(values).view(np.uint8))
#
# File pandas/_libs/lib.pyx:3071, in pandas._libs.lib.map_infer()
#
# Cell In[46], line 6, in get_sentiment(snippet)
#       4 def get_sentiment(snippet):
#       5     #return sid.polarity_scores(snippet)['compound']
# ----> 6     return nlp(snippet)._.polarity
#
# File /opt/anaconda3/envs/tad_courses/lib/python3.11/site-packages/spacy/tokens/underscore.py:48, in Underscore.__getattr__(self, name)
#      46 def __getattr__(self, name: str) -> Any:
#      47     if name not in self._extensions:
# ---> 48         raise AttributeError(Errors.E046.format(name=name))
#      49     default, method, getter, setter = self._extensions[name]
#      50     if getter is not None:
#
# AttributeError: [E046] Can't retrieve unregistered extension attribute 'polarity'. Did you forget to call the `set_extension` method?

# %%
dfs.sort_values('sentiment',inplace=True)
# print beginning of most positive documents
[x[50:150] for x  in dfs[-5:]['opinion_text']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/s0/qj_3vfv57l5bknx99kmph6sc0000gn/T/ipykernel_61113/2230338333.py in ?()
# ----> 1 dfs.sort_values('sentiment',inplace=True)
#       2 # print beginning of most positive documents
#       3 [x[50:150] for x  in dfs[-5:]['opinion_text']]
#
# /opt/anaconda3/envs/tad_courses/lib/python3.11/site-packages/pandas/core/frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    8343             )
#    8344         elif by:
#    8345             # len(by) == 1
#    8346
# -> 8347             k = self._get_label_or_level_values(by[0], axis=axis)
#    8348
#    8349             # need to rewrap column in Series to apply key function
#    8350             if key is not None:
#
# /opt/anaconda3/envs/tad_courses/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, key, axis)
#    1772             values = self.xs(key, axis=first_other_axes)._values
#    1773         elif self._is_level_reference(key, axis=axis):
#    1774             values = self.axes[axis].get_level_values(key)._values
#    1775         else:
# -> 1776             raise KeyError(key)
#    1777
#    1778         # Check for duplicates
#    1779         if values.ndim > 1:
#
# KeyError: 'sentiment'

# %%
# print beginning of most negative documents
[x[50:150] for x  in dfs[:5]['opinion_text']]
# Out:
# ['\n\nThe False Claims Act (FCA) imposes civil liability on any person who knowingly uses a "false recor',
#  ' \n\nWhen an alien is found ineligible to remain in the United States, the process for selecting the c',
#  'he Court. \n\n Petitioner Josue Leocal, a Haitian citizen who is a lawful permanent resident of the Un',
#  " \n\n Respondent Arturo Recuenco was convicted of assault in the second degree based on the jury's fin",
#  'he Court. \n\n InTotten v. United States,92 U.S. 105, 23 L. Ed. 605 (1876), we held that public policy']

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
sid = SentimentIntensityAnalyzer()
# sample 20% of the dataset
dfs = df.sample(frac=.1) 

# apply compound sentiment score to data-frame
def get_sentiment(snippet):
    return sid.polarity_scores(snippet)['compound']
dfs['sentiment_vader'] = dfs['opinion_text'].apply(get_sentiment)
dfs.sort_values('sentiment_vader',inplace=True)
# print beginning of most positive documents
[x[50:150] for x  in dfs[-5:]['opinion_text']]
# Out:
# [" \n\n California's Holocaust Victim Insurance Relief Act of 1999 (HVIRA or Act), Cal. Ins. Code Ann. §",
#  '\n\nThe question before us is one of jurisdiction. An association of nursing homes sued, inter alios, ',
#  "\n\n When a debtor files a Chapter 7 bankruptcy petition, all of the debtor's assets become property o",
#  '. \n\n The State of Alaska has invoked our original jurisdiction to resolve its dispute with the Unite',
#  ".\n\nThe State of Washington, like every other State in the Union, uses interest on lawyers' trust acc"]

# %% [markdown]
# ## Sentiment Analysis with Huggingface

# %%
#!pip install transformers

from tqdm import tqdm as tqdm
from transformers import pipeline, AutoModelForTokenClassification, AutoTokenizer
pipe = pipeline("sentiment-analysis")

# %%
# !pip install torch

from torch.utils.data import Dataset
from tqdm.auto import tqdm

class OpinionDataset(Dataset):
    def __init__(self, df):
        super().__init__()
        self.df = df
    def __len__(self):
        return len(df)

    def __getitem__(self, i):
        return df.iloc[i]["opinion_text"][:512] # BERT max seq length


dataset = OpinionDataset(df)
sentiments = []

for out in tqdm(pipe(dataset, batch_size=16), total=len(dataset)):
        if out['label'] == "NEGATIVE":
            sentiments.append(-1*out['score'])
        else:
            sentiments.append(out['score'])
# Out:
# Collecting torch
#   Downloading torch-2.12.0-cp311-cp311-macosx_14_0_arm64.whl.metadata (31 kB)
# Collecting filelock (from torch)
#   Using cached filelock-3.29.0-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/anaconda3/envs/tad_courses/lib/python3.11/site-packages (from torch) (4.15.0)
# Collecting setuptools<82 (from torch)
#   Using cached setuptools-81.0.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting sympy>=1.13.3 (from torch)
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx>=2.5.1 (from torch)
#   Using cached networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/tad_courses/lib/python3.11/site-packages (from torch) (3.1.6)
# Collecting fsspec>=0.8.5 (from torch)
#   Downloading fsspec-2026.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/tad_courses/lib/python3.11/site-packages (from jinja2->torch) (3.0.2)
# Downloading torch-2.12.0-cp311-cp311-macosx_14_0_arm64.whl (88.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 MB 39.4 MB/s  0:00:02 eta 0:00:01
# Using cached setuptools-81.0.0-py3-none-any.whl (1.1 MB)
# Downloading fsspec-2026.4.0-py3-none-any.whl (203 kB)
# Using cached networkx-3.6.1-py3-none-any.whl (2.1 MB)
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Using cached filelock-3.29.0-py3-none-any.whl (39 kB)
# Installing collected packages: mpmath, sympy, setuptools, networkx, fsspec, filelock, torch
#   Attempting uninstall: setuptools━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/7 [sympy]
#     Found existing installation: setuptools 82.0.1━━━━━━━━━━━━ 1/7 [sympy]
#     Uninstalling setuptools-82.0.1:━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/7 [sympy]
#       Successfully uninstalled setuptools-82.0.1━━━━━━━━━━━━━━━━━━ 2/7 [setuptools]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [torch]32m6/7 [torch]kx]s]
# Successfully installed filelock-3.29.0 fsspec-2026.4.0 mpmath-1.3.0 networkx-3.6.1 setuptools-81.0.0 sympy-1.14.0 torch-2.12.0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 20
#      17 dataset = OpinionDataset(df)
#      18 sentiments = []
# ---> 20 for out in tqdm(pipe(dataset, batch_size=16), total=len(dataset)):
#      21         if out['label'] == "NEGATIVE":
#      22             sentiments.append(-1*out['score'])
#
# NameError: name 'pipe' is not defined

# %%
df['sentiments'] = sentiments
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 df['sentiments'] = sentiments
#
# File /opt/anaconda3/envs/tad_courses/lib/python3.11/site-packages/pandas/core/frame.py:4672, in DataFrame.__setitem__(self, key, value)
#    4669     self._setitem_array([key], value)
#    4670 else:
#    4671     # set column
# -> 4672     self._set_item(key, value)
#
# File /opt/anaconda3/envs/tad_courses/lib/python3.11/site-packages/pandas/core/frame.py:4872, in DataFrame._set_item(self, key, value)
#    4862 def _set_item(self, key, value) -> None:
#    4863     """
#    4864     Add series to DataFrame in specified column.
#    4865
#    (...)   4870     ensure homogeneity.
#    4871     """
# -> 4872     value, refs = self._sanitize_column(value)
#    4874     if (
#    4875         key in self.columns
#    4876         and value.ndim == 1
#    4877         and not isinstance(value.dtype, ExtensionDtype)
#    4878     ):
#    4879         # broadcast across multiple columns if necessary
#    4880         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File /opt/anaconda3/envs/tad_courses/lib/python3.11/site-packages/pandas/core/frame.py:5742, in DataFrame._sanitize_column(self, value)
#    5739     return _reindex_for_setitem(value, self.index)
#    5741 if is_list_like(value):
# -> 5742     com.require_length_match(value, self.index)
#    5743 return sanitize_array(value, self.index, copy=True, allow_2d=True), None
#
# File /opt/anaconda3/envs/tad_courses/lib/python3.11/site-packages/pandas/core/common.py:601, in require_length_match(data, index)
#     597 """
#     598 Check the length of data matches the length of the index.
#     599 """
#     600 if len(data) != len(index):
# --> 601     raise ValueError(
#     602         "Length of values "
#     603         f"({len(data)}) "
#     604         "does not match length of index "
#     605         f"({len(index)})"
#     606     )
#
# ValueError: Length of values (0) does not match length of index (768)

# %%
df.sort_values('sentiments',inplace=True)
# print beginning of most positive documents
[x[50:150] for x  in df[-5:]['opinion_text']]

# %%
# print beginning of most negative documents
[x[50:150] for x  in df[:5]['opinion_text']]

# %% [markdown]
# ## StopWords

# %%
#from nltk.corpus import stopwords
#stopwords = set(stopwords.words('english'))
#stopwords
from spacy.lang.en import stop_words
print (stop_words.STOP_WORDS)
# Out:
# {'fifteen', 'serious', 'were', 'thereby', 'you', 'him', 'how', '’s', 'due', "'ve", 'mine', 'hence', 'other', 'somewhere', 'his', 'after', 'we', 'together', 'another', 'will', "n't", 'latter', 'unless', 'also', 'nowhere', 'all', 'may', 'do', 'though', 'n‘t', 'yours', 'few', 'seem', 'twenty', 'several', 'almost', 'so', 'a', "'d", 'well', 'that', 'for', 'anyone', 'throughout', 'therein', 'further', 'never', 'neither', "'s", 'although', 'us', 'whether', 'used', 'can', 'wherein', 'he', 'hundred', 'herein', 'moreover', 'out', 'third', 'where', 'until', 'whom', 'being', 'same', 'everything', 'beyond', 'enough', 'once', 'towards', 'yet', 'thru', 'noone', 'your', 'name', 'nine', 'forty', 'among', 'either', 'say', 'sixty', 'cannot', '’re', 'eight', 'two', 'up', 'an', 'nevertheless', 'why', 'into', 'anything', 'on', '‘ve', '‘re', 'first', 'therefore', 'without', 'toward', '‘s', 'hereafter', 'have', 'wherever', 'already', 'anyway', 'yourself', 'own', 'above', 'often', 'take', "'ll", 'is', 'really', 'fifty', 'she', 'the', 'again', 'ever', 'below', 'each', 'ours', 'per', 'besides', 'with', 'mostly', 'get', 'front', 'beside', 'whereafter', 'there', 'has', 'i', 'them', 'my', 'does', 'whither', 'be', 'become', 'becomes', 'someone', 'three', 'because', 'at', 'quite', 'seeming', 'its', 'whatever', 'if', 'than', 'move', 'no', 'not', 'had', 'thence', 'hereby', 'which', 'less', 'meanwhile', 'various', 'show', 'most', 'part', 'to', 'next', 'much', 'via', 'anyhow', 'six', 'through', 'beforehand', 'nothing', 'top', 'these', 'whoever', 'alone', 'both', 'within', 'indeed', 'those', '’ll', 'down', 'perhaps', 'too', '‘d', 'else', 'everywhere', 'became', 'must', 'before', 'rather', 'least', 'only', 'ca', 'such', 'their', 'many', 'upon', 'keep', 'made', 'always', 'very', '’d', 'everyone', 'it', 'whose', 'whereas', 'see', 'across', 'about', 'themselves', 'any', 'are', 'except', 'whole', 'when', 'against', 'afterwards', 'ten', 'amongst', 'am', 'around', 'might', 'five', 'herself', 'was', 'as', 'still', 'what', 'call', 'could', 'thereupon', 'myself', 'empty', 'anywhere', 'eleven', 'whence', 'seems', 'regarding', 'hereupon', 'between', 'becoming', 'seemed', 'now', 'whereby', 'please', '’ve', 'and', 'more', 'using', 'but', "'m", 'others', 'during', 'full', 'did', 'should', 'bottom', 'whenever', 'or', 'every', 'himself', 'hers', 're', 'from', 'done', 'somehow', 'yourselves', 'over', 'they', 'by', 'formerly', 'been', 'last', 'back', 'former', 'since', 'here', 'behind', 'would', 'off', 'under', 'then', 'give', 'just', "'re", 'while', 'four', 'doing', 'go', 'one', 'some', 'thus', 'her', 'side', 'make', 'onto', 'otherwise', 'none', 'namely', 'even', 'of', 'elsewhere', 'amount', '’m', 'ourselves', '‘m', 'n’t', 'this', 'sometimes', 'latterly', 'put', 'along', 'however', 'something', 'thereafter', 'who', 'nobody', 'itself', 'twelve', 'our', 'whereupon', 'sometime', 'me', '‘ll', 'in', 'nor'}

# %%
#stopfreq = np.sum([freqs[x] for x in stopwords])
#stopfreq # 174132 for NLTK stopwords
stopwords = stop_words.STOP_WORDS
stopfreq = np.sum([freqs[x] for x in stopwords])
stopfreq
# Out:
# np.int64(191526)

# %%
otherfreq = np.sum([freqs[x] for x in freqs if x not in stopwords])
otherfreq
# Out:
# np.int64(306516)

# %% [markdown]
# ## RegEx

# %% [markdown]
# Please refer to [RegExOne Regular Expressions Lessons](regexone.com) and [the python documentation](https://docs.python.org/3/howto/regex.html).

# %%
import re

docs = dfs[:5]['opinion_text']

# Extract words after justice.
for doc in docs:    
    print(re.findall(r'Justice \w+ ', # pattern to match. always put 'r' in front of string so that backslashes are treated literally.
                     doc,            # string
                     re.IGNORECASE))  # ignore upper/lowercase (optional)
# Out:
# ['Justice Souter ']
# ['JUSTICE STEVENS ', 'JUSTICE SCALIA ', 'Justice Clifford ']
# ['Justice Thomas ', 'Justice Souter ', 'justice system ']
# ['Justice as ']
# ['Justice Breyer ']

# %%
# Extract hyphenated words
for doc in docs:    
    print(re.findall(r'[a-z]+-[a-z]+', 
                     doc,            
                     re.IGNORECASE))
# Out:
# ['eight-level', 'immigration-enforcement', 'Yanez-Garcia', 'Briones-Mata', 'state-law', 'Hinojosa-Lopez', 'Briones-Mata', 'Cabrera-Sosa', 'Restrepo-Aguilar', 'Gonzales-Gomez', 'state-law', 'Palacios-Suarez', 'Ibarra-Galindo', 'state-law', 'Pornes-Garcia', 'Cazarez-Gutierrez', 'state-law', 'Urena-Ramirez', 'state-by', 'misdemeanor-felony', 'one-sided', 'misdemeanor-felony']
# ['second-degree', 'second-degree', 'African-American', 'all-white', 'first-degree', 'second-degree', 'third-degree', 'fourth-degree', 'second-degree', 'third-degree', 'second-degree', 'third-degree', 'third-degree', 'second-degree', 'African-Americans', 'penalty-enhancing', 'Almendarez-Torres', 'Almendarez-Torres', 'post-Winship', 'Almendarez-Torres', 'common-law', 'sanction-specific', 'flat-out', 'common-law', 'common-law', 'th-century', 'fixed-term', 'common-law', 'discre-tion', 'Almendarez-Torres', 'heat-of', 'second-degree', 'second-degree', 'Almendarez-Torres', 'Almendarez-Torres', 'Almendarez-Torres', 'Almendarez-Torres', 'Almendarez-Torres', 'Almendarez-Torres', 'Almendarez-Torres', 'Almendarez-Torres', 'Almendarez-Torres', 'Almendarez-Torres', 'Almendarez-Torres', 'Almendarez-Torres', 'recidivism-based', 'Almendarez-Torres', 'burden-of', 'second-degree', 'Almendarez-Torres', 'status-based', 'second-degree', 'Almendarez-Torres', 'Almendarez-Torres', 'cocaine-only']
# ['month-old', 'first-degree', 'first-degree', 'third-party', 'state-court', 'death-eligible', 'death-eligible', 'death-eligible', 'death-eligible', 'Furman-type', 'well-established', 'guilt-phase', 'Bedau-Radelet', 'bright-line']
# ['year-old', 'first-degree', 'gang-raped', 'context-dependent', 'one-page', 'well-defined', 'post-hoc', 'hand-burning', 'pre-sentence', 'hand-burning', 'state-law', 'guilt-or']
# ['alcohol-related', 'Alcohol-Related', 'www-nrd', 'all-encompassing', 'crime-by', 'strict-liability', 'in-involve', 'risk-based', 'strict-liability']

# %%
# extract citations
for i, doc in enumerate(docs):
    finder = re.finditer('\d+ [^\s]+ \d+', # pattern to match ([^\s] means non-white-space)
                     doc)            # string
    for m in finder: 
        print(i, m.span(),m.group()) # location (start,end) and matching string
# Out:
# 0 (568, 582) 102 Stat. 4469
# 0 (612, 626) 108 Stat. 4320
# 0 (2025, 2037) 2 (Nov. 2005
# 0 (2498, 2511) 1 (Supp. 1997
# 0 (2831, 2843) 543 U.S. 371
# 0 (3882, 3894) 116 F.3d 308
# 0 (4139, 4151) 417 F.3d 934
# 0 (4728, 4740) 316 F.3d 506
# 0 (4820, 4833) 168 F.3d 1271
# 0 (4887, 4899) 130 F.3d 691
# 0 (4950, 4962) 116 F.3d 308
# 0 (5025, 5036) 81 F.3d 998
# 0 (5092, 5103) 74 F.3d 361
# 0 (5153, 5165) 441 F.3d 532
# 0 (5259, 5271) 418 F.3d 692
# 0 (5310, 5322) 280 F.3d 297
# 0 (5520, 5533) 206 F.3d 1337
# 0 (5641, 5653) 171 F.3d 142
# 0 (5709, 5721) 382 F.3d 905
# 0 (5818, 5829) 79 F.3d 315
# 0 (5848, 5861) 547 U.S. 1054
# 0 (6713, 6725) 174 F.3d 580
# 0 (6727, 6740) 582 (CA5 1999
# 0 (7268, 7281) 21 U.S.C. 801
# 0 (8043, 8055) 510 U.S. 471
# 0 (8356, 8367) 341 F.3d 51
# 0 (8369, 8381) 57 (CA1 2003
# 0 (8459, 8473) 681 (App. 1996
# 0 (9014, 9026) 5 (2004), 22
# 0 (9082, 9096) 115 (West 2003
# 0 (9132, 9145) 35 (West 2003
# 0 (9895, 9905) 543 U.S. 1
# 0 (10275, 10292) 198 (Messner 1982
# 0 (12270, 12281) 464 U.S. 16
# 0 (14418, 14430) 540 U.S. 581
# 1 (866, 875) 10 and 20
# 1 (1100, 1108) 10 to 20
# 1 (1751, 1761) 159 N.J. 7
# 1 (1767, 1779) 731 A.2d 485
# 1 (2298, 2306) 3 and 18
# 1 (2638, 2645) 5 to 10
# 1 (2728, 2735) 3 and 5
# 1 (5546, 5558) 397 U.S. 358
# 1 (5725, 5738) 698 A.2d 1265
# 1 (5800, 5811) 477 U.S. 79
# 1 (6996, 7006) 159 N.J. 7
# 1 (7008, 7020) 731 A.2d 485
# 1 (8501, 8513) 526 U.S. 227
# 1 (8734, 8746) 523 U.S. 224
# 1 (11463, 11476) 528 U.S. 1018
# 1 (11826, 11834) 3 and 18
# 1 (12530, 12538) 3 and 22
# 1 (13001, 13013) 508 U.S. 476
# 1 (14250, 14262) 421 U.S. 684
# 1 (14326, 14338) 442 U.S. 510
# 1 (14498, 14510) 432 U.S. 197
# 1 (14970, 14982) 526 U.S. 227
# 1 (17097, 17109) 391 U.S. 145
# 1 (17251, 17263) 397 U.S. 358
# 1 (17519, 17531) 523 U.S. 224
# 1 (17867, 17879) 515 U.S. 506
# 1 (17960, 17972) 508 U.S. 275
# 1 (19051, 19063) 391 U.S. 145
# 1 (20293, 20309) 4 Blackstone 368
# 1 (22082, 22094) 526 U.S. 227
# 1 (22690, 22706) 4 Blackstone 238
# 1 (22993, 23009) 4 Blackstone 343
# 1 (24161, 24177) 3 Blackstone 396
# 1 (24307, 24321) 4 Blackstone 5
# 1 (27243, 27255) 337 U.S. 241
# 1 (28180, 28192) 404 U.S. 443
# 1 (34931, 34943) 421 U.S. 684
# 1 (36520, 36532) 432 U.S. 197
# 1 (37803, 37814) 477 U.S. 79
# 1 (40957, 40969) 523 U.S. 224
# 1 (44178, 44190) 524 U.S. 721
# 1 (46594, 46605) 92 U.S. 214
# 1 (50424, 50436) 421 U.S. 684
# 1 (50594, 50606) 480 U.S. 228
# 1 (53799, 53811) 1137 (rev. 4
# 1 (55749, 55759) 159 N.J. 7
# 1 (55765, 55777) 731 A.2d 485
# 1 (63242, 63254) 497 U.S. 639
# 1 (63295, 63311) 3047 (1990); 497
# 1 (64570, 64582) 523 U.S. 511
# 2 (2389, 2401) 278 Kan. 520
# 2 (2412, 2420) 102 P. 3
# 2 (2796, 2804) 102 P. 3
# 2 (3370, 3383) 544 U.S. 1060
# 2 (3899, 3911) 420 U.S. 469
# 2 (4073, 4086) 544 U.S. 1060
# 2 (6128, 6140) 466 U.S. 380
# 2 (6220, 6232) 459 U.S. 553
# 2 (6296, 6308) 467 U.S. 649
# 2 (6751, 6763) 272 Kan. 894
# 2 (6765, 6776) 40 P.3d 139
# 2 (7858, 7871) 463 U.S. 1032
# 2 (7980, 7992) 497 U.S. 639
# 2 (8080, 8092) 536 U.S. 584
# 2 (8597, 8610) 159 Ariz. 571
# 2 (8612, 8625) 769 P.2d 1017
# 2 (8759, 8772) 865 F.2d 1011
# 2 (10835, 10847) 494 U.S. 299
# 2 (11235, 11247) 494 U.S. 370
# 2 (11539, 11551) 428 U.S. 280
# 2 (11638, 11650) 428 U.S. 325
# 2 (14639, 14652) 191 Ariz. 372
# 2 (14659, 14671) 956 P.2d 499
# 2 (14713, 14725) 135 Ariz. 42
# 2 (14731, 14741) 659 P.2d 1
# 2 (16698, 16710) 408 U.S. 238
# 2 (16785, 16797) 428 U.S. 153
# 2 (17522, 17534) 487 U.S. 164
# 2 (17627, 17639) 462 U.S. 862
# 2 (17816, 17828) 506 U.S. 461
# 2 (17978, 17990) 438 U.S. 586
# 2 (18590, 18602) 337 U.S. 241
# 2 (19087, 19099) 455 U.S. 104
# 2 (19340, 19350) 476 U.S. 1
# 2 (20227, 20239) 481 U.S. 279
# 2 (26924, 26936) 428 U.S. 280
# 2 (27005, 27017) 428 U.S. 325
# 2 (28944, 28956) 494 U.S. 370
# 2 (29035, 29047) 271 U.S. 104
# 2 (29551, 29563) 479 U.S. 538
# 2 (29967, 29980) 206 -207, 165
# 2 (33210, 33220) 185 Ill. 2
# 2 (33232, 33246) 708 N.E.2d 365
# 3 (632, 643) 352 Md. 580
# 3 (650, 660) 724 A.2d 1
# 3 (3896, 3907) 324 Md. 551
# 3 (3909, 3922) 597 A.2d 1359
# 3 (3943, 3956) 503 U.S. 1007
# 3 (7575, 7583) 724 A. 2
# 3 (8063, 8071) 724 A. 2
# 3 (8312, 8320) 724 A. 2
# 3 (8720, 8728) 724 A. 2
# 3 (9111, 9123) 529 U.S. 362
# 3 (9995, 10007) 288 F.3d 629
# 3 (10932, 10945) 537 U.S. 1027
# 3 (12523, 12535) 535 U.S. 685
# 3 (12810, 12821) 538 U.S. 63
# 3 (13444, 13456) 466 U.S. 668
# 3 (15946, 15959) 396 (citing 1
# 3 (19835, 19843) 724 A. 2
# 3 (23283, 23295) 483 U.S. 776
# 3 (23549, 23561) 477 U.S. 168
# 3 (25937, 25945) 724 A. 2
# 3 (26597, 26605) 724 A. 2
# 3 (27914, 27922) 724 A. 2
# 3 (28563, 28571) 724 A. 2
# 3 (29191, 29199) 724 A. 2
# 3 (32033, 32041) 724 A. 2
# 3 (32176, 32184) 724 A. 2
# 3 (33558, 33566) 724 A. 2
# 3 (33934, 33942) 724 A. 2
# 3 (34558, 34566) 724 A. 2
# 3 (43324, 43336) 492 U.S. 302
# 3 (43697, 43709) 455 U.S. 104
# 3 (43893, 43905) 438 U.S. 586
# 3 (44841, 44853) 483 U.S. 776
# 3 (44917, 44929) 477 U.S. 168
# 3 (46541, 46551) 340 Md. 30
# 3 (46553, 46565) 665 A.2d 223
# 3 (46932, 46940) 665 A. 2
# 3 (47217, 47228) 347 Md. 156
# 3 (47239, 47252) 699 A.2d 1170
# 3 (47645, 47653) 665 A. 2
# 3 (48286, 48296) 367 Md. 91
# 3 (48307, 48319) 786 A.2d 631
# 4 (2398, 2411) 1143 (NM 2005
# 4 (2922, 2928) 2 to 1
# 4 (2951, 2963) 470 F.3d 964
# 4 (3754, 3766) 495 U.S. 575
# 4 (3888, 3900) 550 U.S. 192
# 4 (4919, 4932) 1 (No. 810821
# 4 (6956, 6968) 550 U.S. 203
# 4 (7836, 7848) 533 U.S. 167
# 4 (7933, 7945) 348 U.S. 528
# 4 (8062, 8072) 543 U.S. 1

# %%
# baker-bloom economic uncertainty
pattern1 = r'(\b)uncertain[a-z]*'
pattern2 = r'(\b)econom[a-z]*'
pattern3 = r'(\b)congress(\b)|(\b)deficit(\b)|(\b)federal reserve(\b)|(\b)legislation(\b)|(\b)regulation(\b)|(\b)white house(\b)'

# %%
re.search(pattern1,'The White House tried to calm uncertainty in the markets.')
# Out:
# <re.Match object; span=(30, 41), match='uncertainty'>

# %%
re.search(pattern2,'The Congress tried to calm uncertainty in the economy.')
# Out:
# <re.Match object; span=(46, 53), match='economy'>

# %%
re.search(pattern3,'The Congress tried to calm uncertainty in the markets.')

# %%
re.search(pattern3,'The Congress tried to calm uncertainty in the markets.', re.IGNORECASE)
# Out:
# <re.Match object; span=(4, 12), match='Congress'>

# %%
def indicates_uncertainty(doc):
    m1 = re.search(pattern1, doc, re.IGNORECASE)
    m2 = re.search(pattern2, doc, re.IGNORECASE)
    m3 = re.search(pattern3, doc, re.IGNORECASE)
    if m1 and m2 and m3:
        return True
    else:
        return False

# %%
indicates_uncertainty('The White House tried to calm uncertainty in the economy.')
# Out:
# True

# %%
indicates_uncertainty('The White House tried to calm uncertainty in the markets.')
# Out:
# False

# %%
df['uncertainty'] = df['opinion_text'].apply(indicates_uncertainty)

# %%
df.uncertainty.mean()
# Out:
# np.float64(0.057291666666666664)

# %%
df.groupby('year')['uncertainty'].mean().plot()
# Out:
# <Axes: xlabel='year'>

# %% [markdown]
# ## WordNet

# %% [markdown]
# These examples are based on the [NLTK tutorial](https://www.nltk.org/howto/wordnet.html).

# %%
#nltk.download('wordnet')
from nltk.corpus import wordnet as wn

# %%
wn.synsets('judge')
# Out:
# [Synset('judge.n.01'),
#  Synset('evaluator.n.01'),
#  Synset('judge.v.01'),
#  Synset('evaluate.v.02'),
#  Synset('estimate.v.01'),
#  Synset('pronounce.v.02'),
#  Synset('judge.v.05')]

# %%
wn.synsets('judge', pos='v') # can filter on part of speech
# Out:
# [Synset('judge.v.01'),
#  Synset('evaluate.v.02'),
#  Synset('estimate.v.01'),
#  Synset('pronounce.v.02'),
#  Synset('judge.v.05')]

# %%
judge = wn.synset('judge.n.01')
judge
# Out:
# Synset('judge.n.01')

# %%
judge.definition()
# Out:
# 'a public official authorized to decide questions brought before a court of justice'

# %%
wn.synset('estimate.v.01').examples()
# Out:
# ['I estimate this chicken to weigh three pounds']

# %%
# categories to which "judge.n.01" belongs
judge.hypernyms()
# Out:
# [Synset('official.n.01'), Synset('adjudicator.n.01')]

# %%
# the root category of "judge.n.01"
judge.root_hypernyms()
# Out:
# [Synset('entity.n.01')]

# %%
wn.synset('estimate.v.01').root_hypernyms()
# Out:
# [Synset('think.v.03')]

# %%
# members of the "judge.n.01" category
judge.hyponyms()
# Out:
# [Synset('trial_judge.n.01'),
#  Synset('daniel.n.02'),
#  Synset('doge.n.01'),
#  Synset('justiciar.n.01'),
#  Synset('trier.n.01'),
#  Synset('recorder.n.03'),
#  Synset('praetor.n.01'),
#  Synset('qadi.n.01'),
#  Synset('ordinary.n.01'),
#  Synset('chief_justice.n.01'),
#  Synset('magistrate.n.01'),
#  Synset('alcalde.n.01')]

# %%
# "holonym" is a part of a whole
juror = wn.synset('juror.n.01')
juror.member_holonyms()
# Out:
# [Synset('jury.n.01')]

# %%
# can find "lowest common hypernyms":
judge.lowest_common_hypernyms(juror)
# Out:
# [Synset('person.n.01')]

# %%
# "lemmas" are specific senses of a specific word.
judge.lemmas()
# Out:
# [Lemma('judge.n.01.judge'),
#  Lemma('judge.n.01.justice'),
#  Lemma('judge.n.01.jurist')]

# %%
[lemma.name() for lemma in judge.lemmas()]
# Out:
# ['judge', 'justice', 'jurist']

# %%
# lemmas have additional properties
judge_lemma = judge.lemmas()[0]
judge_lemma.derivationally_related_forms()
# Out:
# [Lemma('judicial.s.01.judicial'),
#  Lemma('judicial.a.02.judicial'),
#  Lemma('judicial.a.03.judicial'),
#  Lemma('judgeship.n.01.judgeship'),
#  Lemma('judge.v.05.judge'),
#  Lemma('judge.v.05.adjudicate'),
#  Lemma('decide.v.02.adjudicate')]

# %%
good = wn.synset('good.a.01').lemmas()[0]
good.antonyms()
# Out:
# [Lemma('bad.a.01.bad')]

# %%
# verb frames summarize the different semantic contexts that a verb can be used
judge_verb = wn.synset('estimate.v.01').lemmas()[4]
judge_verb.frame_strings()
# Out:
# ['Somebody judge something', 'Somebody judge PP', 'Somebody judge that CLAUSE']

# %%
# measure similarity in the dictionary between words
judge.path_similarity(wn.synset('juror.n.01'))
# Out:
# 0.1111111111111111

# %%
judge.path_similarity(wn.synset('cat.n.01'))
# Out:
# 0.08333333333333333

# %%
# Wu-Palmer similarity.
judge.wup_similarity(juror)
# Out:
# 0.5454545454545454

# %%
judge.wup_similarity(wn.synset('cat.n.01'))
# Out:
# 0.5217391304347826

# %%
# Can iterate over all synsets; e.g., all nouns:
for synset in list(wn.all_synsets('n')):
    if 'judg' in str(synset):
        print(synset)
# Out:
# Synset('judgeship.n.01')
# Synset('judgment.n.02')
# Synset('value_judgment.n.01')
# Synset('judgment.n.03')
# Synset('confession_of_judgment.n.01')
# Synset('default_judgment.n.01')
# Synset('final_judgment.n.01')
# Synset('judgment_in_personam.n.01')
# Synset('judgment_in_rem.n.01')
# Synset('judgment_of_dismissal.n.01')
# Synset('judgment_on_the_merits.n.01')
# Synset('summary_judgment.n.01')
# Synset('judgment.n.06')
# Synset('judgment.n.04')
# Synset('prejudgment.n.01')
# Synset('judgment.n.01')
# Synset('judges.n.01')
# Synset('back_judge.n.01')
# Synset('field_judge.n.01')
# Synset('judge.n.01')
# Synset('judge_advocate.n.02')
# Synset('judge_advocate.n.01')
# Synset('judge_advocate_general.n.01')
# Synset('line_judge.n.01')
# Synset('side_judge.n.01')
# Synset('trial_judge.n.01')
# Synset('judgment_lien.n.01')
# Synset('judgment_day.n.01')

# %% [markdown]
# **Exercise**. Use wordnet to expand the set of words in the Baker-Bloom-Davis dictionary and re-compute policy uncertainty scores by year.
